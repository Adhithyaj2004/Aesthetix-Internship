# %%
  import pandas as pd
  df = pd.read_csv("/content/customer life time csv.csv")
  df
# Out:
#             id  gender   area qualification         income  marital_status  \
# 0            1    Male  Urban      Bachelor         5L-10L               1
# 1            2    Male  Rural   High School         5L-10L               0
# 2            3    Male  Urban      Bachelor         5L-10L               1
# 3            4  Female  Rural   High School         5L-10L               0
# 4            5    Male  Urban   High School  More than 10L               1
# ...        ...     ...    ...           ...            ...             ...
# 148982  148983    Male  Rural      Bachelor         5L-10L               1
# 148983  148984    Male  Urban   High School         5L-10L               0
# 148984  148985  Female  Urban   High School          2L-5L               1
# 148985  148986    Male  Rural      Bachelor         5L-10L               0
# 148986  148987  Female  Urban      Bachelor         5L-10L               1
#
# ...

# %%
df.head()
# Out:
#    id  gender   area qualification         income  marital_status  vintage  \
# 0   1    Male  Urban      Bachelor         5L-10L               1        5
# 1   2    Male  Rural   High School         5L-10L               0        8
# 2   3    Male  Urban      Bachelor         5L-10L               1        8
# 3   4  Female  Rural   High School         5L-10L               0        7
# 4   5    Male  Urban   High School  More than 10L               1        6
#
#    claim_amount num_policies policy type_of_policy      cltv
# 0          5790  More than 1      A       Platinum   64308.0
# 1          5080  More than 1      A       Platinum  515400.0
# 2          2599  More than 1      A       Platinum   64212.0
# 3             0  More than 1      A       Platinum   97920.0
# 4          3508  More than 1      A           Gold   59736.0

# %%
df.tail(10)
# Out:
#             id  gender   area qualification  income  marital_status  vintage  \
# 148977  148978  Female  Urban      Bachelor   2L-5L               0        6
# 148978  148979    Male  Urban      Bachelor  5L-10L               1        6
# 148979  148980    Male  Urban      Bachelor  5L-10L               1        4
# 148980  148981  Female  Rural   High School  5L-10L               1        6
# 148981  148982    Male  Urban   High School  5L-10L               0        4
# 148982  148983    Male  Rural      Bachelor  5L-10L               1        6
# 148983  148984    Male  Urban   High School  5L-10L               0        6
# 148984  148985  Female  Urban   High School   2L-5L               1        4
# 148985  148986    Male  Rural      Bachelor  5L-10L               0        1
# 148986  148987  Female  Urban      Bachelor  5L-10L               1        4
#
#         claim_amount num_policies policy type_of_policy  cltv
# ...

# %%
df.shape
# Out:
# (148987, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148987 entries, 0 to 148986
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   id              148987 non-null  int64
#  1   gender          148987 non-null  object
#  2   area            148987 non-null  object
#  3   qualification   148987 non-null  object
#  4   income          148987 non-null  object
#  5   marital_status  148987 non-null  int64
#  6   vintage         148987 non-null  int64
#  7   claim_amount    148987 non-null  int64
#  8   num_policies    148987 non-null  object
#  9   policy          148987 non-null  object
#  10  type_of_policy  148987 non-null  object
#  11  cltv            89392 non-null   float64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 13.6+ MB

# %%
df.isnull()
# Out:
#            id  gender   area  qualification  income  marital_status  vintage  \
# 0       False   False  False          False   False           False    False
# 1       False   False  False          False   False           False    False
# 2       False   False  False          False   False           False    False
# 3       False   False  False          False   False           False    False
# 4       False   False  False          False   False           False    False
# ...       ...     ...    ...            ...     ...             ...      ...
# 148982  False   False  False          False   False           False    False
# 148983  False   False  False          False   False           False    False
# 148984  False   False  False          False   False           False    False
# 148985  False   False  False          False   False           False    False
# 148986  False   False  False          False   False           False    False
#
# ...

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 148982    False
# 148983    False
# 148984    False
# 148985    False
# 148986    False
# Length: 148987, dtype: bool

# %%
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'income', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')

# %%
df['area'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
df['area'].nunique()
# Out:
# 2

# %%
df['gender']
# Out:
# 0           Male
# 1           Male
# 2           Male
# 3         Female
# 4           Male
#            ...
# 148982      Male
# 148983      Male
# 148984    Female
# 148985      Male
# 148986    Female
# Name: gender, Length: 148987, dtype: object

# %%
df[['gender','income']]
# Out:
#         gender         income
# 0         Male         5L-10L
# 1         Male         5L-10L
# 2         Male         5L-10L
# 3       Female         5L-10L
# 4         Male  More than 10L
# ...        ...            ...
# 148982    Male         5L-10L
# 148983    Male         5L-10L
# 148984  Female          2L-5L
# 148985    Male         5L-10L
# 148986  Female         5L-10L
#
# [148987 rows x 2 columns]

# %%
df.rename(columns={'income':'LPA'},inplace=True)
df['LPA']
# Out:
# 0                5L-10L
# 1                5L-10L
# 2                5L-10L
# 3                5L-10L
# 4         More than 10L
#               ...
# 148982           5L-10L
# 148983           5L-10L
# 148984            2L-5L
# 148985           5L-10L
# 148986           5L-10L
# Name: LPA, Length: 148987, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'LPA', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')
# Index(['id', 'gender', 'area', 'qualification', 'LPA', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy',
#        'cltv'],
#       dtype='object')

# %%
df.drop('cltv',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['id', 'gender', 'area', 'qualification', 'LPA', 'marital_status',
#        'vintage', 'claim_amount', 'num_policies', 'policy', 'type_of_policy'],
#       dtype='object')

# %%
claims=df.groupby('id')['claim_amount'].sum()
claims
# Out:
# id
# 1         5790
# 2         5080
# 3         2599
# 4            0
# 5         3508
#           ...
# 148983       0
# 148984       0
# 148985    3323
# 148986    2886
# 148987    5939
# Name: claim_amount, Length: 148987, dtype: int64

# %%
claims.plot(kind='line ')
# Out:
# <Axes: xlabel='id'>
